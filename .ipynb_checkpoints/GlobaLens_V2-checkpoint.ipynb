# %%
#import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import math
import statsmodels.api as sm

# %%
df = pd.read_csv(r"C:\Users\thema\OneDrive\Projects\__CTP4900__\Data\world_Bank.csv")

# %%
df.head(10)
# Out:
#          Series Name  Series Code         Country Name Country Code  \
# 0  Population, total  SP.POP.TOTL          Afghanistan          AFG
# 1  Population, total  SP.POP.TOTL              Albania          ALB
# 2  Population, total  SP.POP.TOTL              Algeria          DZA
# 3  Population, total  SP.POP.TOTL       American Samoa          ASM
# 4  Population, total  SP.POP.TOTL              Andorra          AND
# 5  Population, total  SP.POP.TOTL               Angola          AGO
# 6  Population, total  SP.POP.TOTL  Antigua and Barbuda          ATG
# 7  Population, total  SP.POP.TOTL            Argentina          ARG
# 8  Population, total  SP.POP.TOTL              Armenia          ARM
# 9  Population, total  SP.POP.TOTL                Aruba          ABW
#
#   1999 [YR1999] 2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003]  \
# 0      19262847      19542982      19688632      21000256      22645130
# 1       3108778       3089027       3060173       3051010       3039616
# 2      30346083      30774621      31200985      31624696      32055883
# 3         57594         58230         58324         58177         57941
# 4         65655         66097         67820         70849         73907
# 5      15870753      16394062      16941587      17516139      18124342
# 6         73821         75055         76215         77195         78075
# 7      36653031      37070774      37480493      37885028      38278164
# 8       3206030       3168523       3133133       3105037       3084102
# 9         86867         89101         90691         91781         92701
#
#   2004 [YR2004]  ... 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# 0      23553551  ...      28189672      29249157      30466479      31541209
# 1       3026939  ...       2913021       2905195       2900401       2895092
# 2      32510186  ...      35856344      36543541      37260563      38000626
# 3         57626  ...         54849         54310         53691         52995
# 4         76933  ...         71519         70567         71013         71367
# 5      18771125  ...      23364185      24259111      25188292      26147002
# 6         78941  ...         85695         86729         87674         88497
# 7      38668796  ...      40788453      41261490      41733271      42202935
# 8       3065745  ...       2946293       2928976       2914421       2901385
# 9         93540  ...        100341        101288        102112        102880
#
#   2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 0      32716210      33753499      34636207      35643418      36686784
# 1       2889104       2880703       2876101       2873457       2866376
# 2      38760168      39543154      40339329      41136546      41927007
# 3         52217         51368         50448         49463         48424
# 4         71621         71746         72540         73837         75013
# 5      27128337      28127721      29154746      30208628      31273533
# 6         89236         89941         90564         91119         91626
# 7      42669500      43131966      43590368      44044811      44494502
# 8       2889930       2878595       2865835       2851923       2836557
# 9        103594        104257        104874        105439        105962
#
#   2019 [YR2019]
# 0      37769499
# 1       2854191
# 2      42705368
# 3         47321
# 4         76343
# 5      32353588
# 6         92117
# 7      44938712
# 8       2820602
# 9        106442
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Modify the dataframe to better fit the model

# %%
df_melt = pd.melt(df, id_vars=['Series Name', 'Series Code', 'Country Name', 'Country Code'], 
                  var_name='Year', value_name='Value')

# %%
df_melt.head()
# Out:
#          Series Name  Series Code    Country Name Country Code           Year  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  1999 [YR1999]
# 1  Population, total  SP.POP.TOTL         Albania          ALB  1999 [YR1999]
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  1999 [YR1999]
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM  1999 [YR1999]
# 4  Population, total  SP.POP.TOTL         Andorra          AND  1999 [YR1999]
#
#       Value
# 0  19262847
# 1   3108778
# 2  30346083
# 3     57594
# 4     65655

# %%
df_melt['Year'] = df_melt['Year'].str.extract('(\d{4})')[0]

# %%
df_restructured = df_melt.pivot_table(index=['Country Name', 'Country Code', 'Year'], 
                                      columns='Series Name', 
                                      values='Value', 
                                      aggfunc='first').reset_index()

# %%
df_restructured.head()
# Out:
# Series Name Country Name Country Code  Year  \
# 0            Afghanistan          AFG  1999
# 1            Afghanistan          AFG  2000
# 2            Afghanistan          AFG  2001
# 3            Afghanistan          AFG  2002
# 4            Afghanistan          AFG  2003
#
# Series Name Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                      154.416
# 1                                                      152.572
# 2                                                      150.863
# 3                                                      148.141
# 4                                                       143.37
#
# Series Name Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                             38.6278918638443
# 4                                             37.4188554431481
#
# Series Name Births attended by skilled health staff (% of total)  \
# 0                                                           ..
# 1                                                         12.4
# 2                                                           ..
# 3                                                           ..
# 4                                                         14.3
#
# Series Name CO2 emissions (metric tons per capita)  \
# 0                               0.0582468417051747
# 1                               0.0551666066110075
# 2                               0.0552927191691124
# 3                               0.0668101379335566
# 4                               0.0730049683971786
#
# Series Name Contraceptive prevalence, any method (% of married women ages 15-49)  \
# 0                                                           ..
# 1                                                          5.3
# 2                                                           ..
# 3                                                           ..
# 4                                                         10.3
#
# Series Name Electric power consumption (kWh per capita)  \
# 0                                                    ..
# 1                                                    ..
# 2                                                    ..
# 3                                                    ..
# 4                                                    ..
#
# Series Name Energy use (kg of oil equivalent per capita)  ...  \
# 0                                                     ..  ...
# 1                                                     ..  ...
# 2                                                     ..  ...
# 3                                                     ..  ...
# 4                                                     ..  ...
#
# Series Name Prevalence of HIV, total (% of population ages 15-49)  \
# 0                                                          0.1
# 1                                                          0.1
# 2                                                          0.1
# 3                                                          0.1
# 4                                                          0.1
#
# Series Name Prevalence of underweight, weight for age (% of children under 5)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                                           ..
# 4                                                           ..
#
# Series Name Primary completion rate, total (% of relevant age group)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                                           ..
# 4                                                           ..
#
# Series Name Revenue, excluding grants (% of GDP)  \
# 0                                             ..
# 1                                             ..
# 2                                             ..
# 3                                             ..
# 4                                             ..
#
# Series Name School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                            0
# 3                                                           ..
# 4                                            0.544260025024414
#
# Series Name School enrollment, secondary (% gross)  \
# 0                                               ..
# 1                                               ..
# 2                                 12.3246202468872
# 3                                               ..
# 4                                 12.5488901138306
#
# Series Name Start-up procedures to register a business (number)  \
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                                           ..
# 4                                                           ..
#
# Series Name Surface area (sq. km) Total debt service (% of GNI)  \
# 0                          652860                            ..
# 1                          652860                            ..
# 2                          652860                            ..
# 3                          652860                            ..
# 4                          652860                            ..
#
# Series Name Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)
# 0                                                           ..
# 1                                                           ..
# 2                                                           ..
# 3                                            0.372506682976489
# 4                                            0.405407508087606
#
# [5 rows x 54 columns]

# %%
# replace column names to have '_' over ' '
df_restructured.columns.name = None  # Remove the name for columns
df_restructured.rename(columns=lambda x: x.replace(', ', '_').replace(' ', '_').lower(), inplace=True)

# %%
df_restructured = df_restructured.replace('..', np.nan)

# %%
columns_to_exclude = ['country_name', 'country_code', 'Series_Name']
for column in df_restructured.columns:    
    if column not in columns_to_exclude and df_restructured[column].dtype == 'object':
        df_restructured[column] = df_restructured[column].astype(float)

# %% [markdown]
# ## Modelling phase

# %% [markdown]
# ### 2nd iteration

# %%
remove_cols = ['births_attended_by_skilled_health_staff_(%_of_total)',
 'co2_emissions_(metric_tons_per_capita)',
 'electric_power_consumption_(kwh_per_capita)',
 'energy_use_(kg_of_oil_equivalent_per_capita)',
 'immunization_measles_(%_of_children_ages_12-23_months)',
 'mobile_cellular_subscriptions_(per_100_people)',
 'personal_remittances_paid_(current_us$)',
 'agriculture_forestry_and_fishing_value_added_(%_of_gdp)',
 'exports_of_goods_and_services_(%_of_gdp)',
 'gdp_(current_us$)',
 'gdp_growth_(annual_%)',
 'gdp_per_capita_(current_us$)',
 'gross_capital_formation_(%_of_gdp)',
 'imports_of_goods_and_services_(%_of_gdp)',
 'industry_(including_construction)_value_added_(%_of_gdp)',
 'inflation_gdp_deflator_(annual_%)',
 'market_capitalization_of_listed_domestic_companies_(%_of_gdp)',
 'merchandise_trade_(%_of_gdp)',
 'military_expenditure_(%_of_gdp)',
 'revenue_excluding_grants_(%_of_gdp)',
 'water_productivity_total_(constant_2015_us$_gdp_per_cubic_meter_of_total_freshwater_withdrawal)',
 'births_attended_by_skilled_health_staff_(%_of_total)',
 'contraceptive_prevalence_any_method_(%_of_married_women_ages_15-49)',
 'electric_power_consumption_(kwh_per_capita)',
 'energy_use_(kg_of_oil_equivalent_per_capita)',
 'external_debt_stocks_total_(dod_current_us$)',
 'high-technology_exports_(%_of_manufactured_exports)',
 'income_share_held_by_lowest_20%',
 'market_capitalization_of_listed_domestic_companies_(%_of_gdp)',
 'poverty_headcount_ratio_at_national_poverty_lines_(%_of_population)',
 'prevalence_of_underweight_weight_for_age_(%_of_children_under_5)',
 'revenue_excluding_grants_(%_of_gdp)',
 'total_debt_service_(%_of_gni)']

# %%
good_cols = [col for col in df_restructured.columns if col not in remove_cols]
good_cols.remove('country_name')
good_cols.remove('country_code')
good_cols
# Out:
# ['year',
#  'adolescent_fertility_rate_(births_per_1,000_women_ages_15-19)',
#  'fertility_rate_total_(births_per_woman)',
#  'foreign_direct_investment_net_(bop_current_us$)',
#  'foreign_direct_investment_net_inflows_(bop_current_us$)',
#  'forest_area_(sq._km)',
#  'gni_per_capita_atlas_method_(current_us$)',
#  'gni_per_capita_ppp_(current_international_$)',
#  'gni_atlas_method_(current_us$)',
#  'gni_ppp_(current_international_$)',
#  'inflation_consumer_prices_(annual_%)',
#  'life_expectancy_at_birth_total_(years)',
#  'mortality_rate_under-5_(per_1,000_live_births)',
#  'net_oda_received_per_capita_(current_us$)',
#  'net_barter_terms_of_trade_index_(2015_=_100)',
#  'net_migration',
#  'population_growth_(annual_%)',
#  'population_total',
#  'prevalence_of_hiv_total_(%_of_population_ages_15-49)',
#  'primary_completion_rate_total_(%_of_relevant_age_group)',
#  'school_enrollment_primary_and_secondary_(gross)_gender_parity_index_(gpi)',
#  'school_enrollment_secondary_(%_gross)',
#  'start-up_procedures_to_register_a_business_(number)',
#  'surface_area_(sq._km)']

# %%
df_non_object.columns
# Out:
# Index(['year', 'adolescent_fertility_rate_(births_per_1,000_women_ages_15-19)',
#        'agriculture_forestry_and_fishing_value_added_(%_of_gdp)',
#        'births_attended_by_skilled_health_staff_(%_of_total)',
#        'co2_emissions_(metric_tons_per_capita)',
#        'contraceptive_prevalence_any_method_(%_of_married_women_ages_15-49)',
#        'electric_power_consumption_(kwh_per_capita)',
#        'energy_use_(kg_of_oil_equivalent_per_capita)',
#        'exports_of_goods_and_services_(%_of_gdp)',
#        'external_debt_stocks_total_(dod_current_us$)',
#        'fertility_rate_total_(births_per_woman)',
#        'foreign_direct_investment_net_(bop_current_us$)',
#        'foreign_direct_investment_net_inflows_(bop_current_us$)',
#        'forest_area_(sq._km)', 'gdp_(current_us$)', 'gdp_growth_(annual_%)',
#        'gdp_per_capita_(current_us$)',
#        'gni_per_capita_atlas_method_(current_us$)',
#        'gni_per_capita_ppp_(current_international_$)',
#        'gni_atlas_method_(current_us$)', 'gni_ppp_(current_international_$)',
#        'gross_capital_formation_(%_of_gdp)',
#        'high-technology_exports_(%_of_manufactured_exports)',
#        'immunization_measles_(%_of_children_ages_12-23_months)',
#        'imports_of_goods_and_services_(%_of_gdp)',
#        'income_share_held_by_lowest_20%',
#        'industry_(including_construction)_value_added_(%_of_gdp)',
#        'inflation_gdp_deflator_(annual_%)',
#        'inflation_consumer_prices_(annual_%)',
#        'life_expectancy_at_birth_total_(years)',
#        'market_capitalization_of_listed_domestic_companies_(%_of_gdp)',
#        'merchandise_trade_(%_of_gdp)', 'military_expenditure_(%_of_gdp)',
#        'mobile_cellular_subscriptions_(per_100_people)',
#        'mortality_rate_under-5_(per_1,000_live_births)',
#        'net_oda_received_per_capita_(current_us$)',
#        'net_barter_terms_of_trade_index_(2015_=_100)', 'net_migration',
#        'personal_remittances_paid_(current_us$)',
#        'population_growth_(annual_%)', 'population_total',
#        'poverty_headcount_ratio_at_national_poverty_lines_(%_of_population)',
#        'prevalence_of_hiv_total_(%_of_population_ages_15-49)',
#        'prevalence_of_underweight_weight_for_age_(%_of_children_under_5)',
#        'primary_completion_rate_total_(%_of_relevant_age_group)',
#        'revenue_excluding_grants_(%_of_gdp)',
#        'school_enrollment_primary_and_secondary_(gross)_gender_parity_index_(gpi)',
#        'school_enrollment_secondary_(%_gross)',
#        'start-up_procedures_to_register_a_business_(number)',
#        'surface_area_(sq._km)', 'total_debt_service_(%_of_gni)',
#        'water_productivity_total_(constant_2015_us$_gdp_per_cubic_meter_of_total_freshwater_withdrawal)'],
#       dtype='object')

# %%
scaler = StandardScaler()

# %%
f = open('summary.txt', 'w')
good_features = []
df_non_object = df_restructured.select_dtypes(include=[ 'number' ])
for col in df_non_object.columns:
    df_v2 = df_restructured[[col, 'gdp_(current_us$)']].dropna()
    
    scaled_array = scaler.fit_transform(df_v2)
    df_v2 = pd.DataFrame(scaled_array, columns=df_v2.columns)
    
    X = df_v2[col]
    y = df_v2['gdp_(current_us$)']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 1234)

    X_train = sm.add_constant(X_train)
    X_test = sm.add_constant(X_test)
    
    lin_reg = sm.OLS(y_train, X_train).fit()

    # Predict on the testing set
    y_pred = lin_reg.predict(X_test)

    # Calculate MSE using the testing set
    mse = ((y_test - y_pred) ** 2).mean()

    print(f"Test RMSE: {math.sqrt(mse)}, mean_val: {y_pred.mean()}")
    print(lin_reg.summary())
    f.write(str(lin_reg.summary()))
    adjusted_r_squared = lin_reg.rsquared_adj
    if adjusted_r_squared > 0.1:
        good_features.append(col)
# Out:
# Test RMSE: 0.9637463937374137, mean_val: 0.003519043915610512
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     16.76
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           4.35e-05
# Time:                        23:36:55   Log-Likelihood:                -4961.5
# No. Observations:                3481   AIC:                             9927.
# Df Residuals:                    3479   BIC:                             9939.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.017      0.124      0.901      -0.031       0.036
# year           0.0699      0.017      4.093      0.000       0.036       0.103
# ==============================================================================
# Omnibus:                     5406.489   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2070091.764
# Skew:                           9.924   Prob(JB):                         0.00
# Kurtosis:                     120.807   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.9563651467681819, mean_val: -0.0003300615320119384
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     83.85
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           8.89e-20
# Time:                        23:36:55   Log-Likelihood:                -4928.4
# No. Observations:                3481   AIC:                             9861.
# Df Residuals:                    3479   BIC:                             9873.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# const                                                             0.0013      0.017      0.080      0.937      -0.032       0.034
# adolescent_fertility_rate_(births_per_1,000_women_ages_15-19)    -0.1555      0.017     -9.157      0.000      -0.189      -0.122
# ==============================================================================
# Omnibus:                     5433.757   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2158554.254
# Skew:                          10.010   Prob(JB):                         0.00
# Kurtosis:                     123.339   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.8131158900703144, mean_val: -0.0020336595205214664
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     83.81
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           9.41e-20
# Time:                        23:36:55   Log-Likelihood:                -4688.2
# No. Observations:                3244   AIC:                             9380.
# Df Residuals:                    3242   BIC:                             9393.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                       0.0060      0.018      0.331      0.741      -0.029       0.041
# agriculture_forestry_and_fishing_value_added_(%_of_gdp)    -0.1667      0.018     -9.155      0.000      -0.202      -0.131
# ==============================================================================
# Omnibus:                     4853.176   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1448957.783
# Skew:                           9.287   Prob(JB):                         0.00
# Kurtosis:                     104.857   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 1.0230134496430183, mean_val: 0.0037586911775912
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     20.30
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           7.06e-06
# Time:                        23:36:56   Log-Likelihood:                -2482.8
# No. Observations:                1766   AIC:                             4970.
# Df Residuals:                    1764   BIC:                             4981.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.0039      0.024     -0.167      0.868      -0.050       0.042
# births_attended_by_skilled_health_staff_(%_of_total)     0.1052      0.023      4.505      0.000       0.059       0.151
# ==============================================================================
# Omnibus:                     2425.466   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           408045.689
# Skew:                           7.910   Prob(JB):                         0.00
# Kurtosis:                      75.767   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.8731346570994717, mean_val: 0.003728275598457111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     171.9
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           2.89e-38
# Time:                        23:36:56   Log-Likelihood:                -4442.7
# No. Observations:                3143   AIC:                             8889.
# Df Residuals:                    3141   BIC:                             8901.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                      0.0066      0.018      0.370      0.711      -0.028       0.041
# co2_emissions_(metric_tons_per_capita)     0.2298      0.018     13.109      0.000       0.195       0.264
# ==============================================================================
# Omnibus:                     4569.885   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1260993.520
# Skew:                           8.787   Prob(JB):                         0.00
# Kurtosis:                      99.541   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.9387016465460007, mean_val: 0.011603884044785113
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     28.12
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           1.63e-07
# Time:                        23:36:56   Log-Likelihood:                -808.66
# No. Observations:                 577   AIC:                             1621.
# Df Residuals:                     575   BIC:                             1630.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                   0.0047      0.041      0.116      0.908      -0.076       0.085
# contraceptive_prevalence_any_method_(%_of_married_women_ages_15-49)     0.2134      0.040      5.303      0.000       0.134       0.292
# ==============================================================================
# Omnibus:                      889.169   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           202805.706
# Skew:                           8.862   Prob(JB):                         0.00
# Kurtosis:                      93.119   Cond. No.                         1.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 1.166868925933901, mean_val: -0.014601151552002093
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     72.19
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           4.09e-17
# Time:                        23:36:56   Log-Likelihood:                -2364.2
# No. Observations:                1760   AIC:                             4732.
# Df Residuals:                    1758   BIC:                             4743.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.0150      0.022     -0.677      0.498      -0.058       0.028
# electric_power_consumption_(kwh_per_capita)     0.1889      0.022      8.497      0.000       0.145       0.232
# ==============================================================================
# Omnibus:                     2443.482   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           482160.290
# Skew:                           7.994   Prob(JB):                         0.00
# Kurtosis:                      82.494   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.6465961155530954, mean_val: 0.0067078399067793965
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     71.58
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           5.28e-17
# Time:                        23:36:56   Log-Likelihood:                -2750.6
# No. Observations:                1874   AIC:                             5505.
# Df Residuals:                    1872   BIC:                             5516.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                            0.0074      0.024      0.306      0.760      -0.040       0.055
# energy_use_(kg_of_oil_equivalent_per_capita)     0.2053      0.024      8.461      0.000       0.158       0.253
# ==============================================================================
# Omnibus:                     2498.388   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           375701.772
# Skew:                           7.537   Prob(JB):                         0.00
# Kurtosis:                      70.708   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 1.255834005603183, mean_val: -0.005343807147296326
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     36.19
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           2.01e-09
# Time:                        23:36:56   Log-Likelihood:                -4049.5
# No. Observations:                3040   AIC:                             8103.
# Df Residuals:                    3038   BIC:                             8115.
# Df Model:                           1
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -0.0067      0.017     -0.401      0.688      -0.039       0.026
# exports_of_goods_and_services_(%_of_gdp)    -0.0989      0.016     -6.015      0.000      -0.131      -0.067
# ==============================================================================
# Omnibus:                     4430.415   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1207098.241
# Skew:                           8.828   Prob(JB):                         0.00
# Kurtosis:                      99.010   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.3994401091101481, mean_val: 0.009546345634315468
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                 1.288e+04
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):               0.00
# Time:                        23:36:56   Log-Likelihood:                -791.66
# No. Observations:                1963   AIC:                             1587.
# Df Residuals:                    1961   BIC:                             1598.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                           -0.0019      0.008     -0.228      0.819      -0.018       0.014
# external_debt_stocks_total_(dod_current_us$)     0.9251      0.008    113.498      0.000       0.909       0.941
# ==============================================================================
# Omnibus:                     1050.615   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           211925.841
# Skew:                           1.390   Prob(JB):                         0.00
# Kurtosis:                      53.826   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 1.0558621537457225, mean_val: -0.006996165281926692
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     88.32
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           9.95e-21
# Time:                        23:36:56   Log-Likelihood:                -4694.2
# No. Observations:                3382   AIC:                             9392.
# Df Residuals:                    3380   BIC:                             9405.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      -0.0039      0.017     -0.237      0.813      -0.037       0.029
# fertility_rate_total_(births_per_woman)    -0.1572      0.017     -9.398      0.000      -0.190      -0.124
# ==============================================================================
# Omnibus:                     5282.335   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2133245.487
# Skew:                          10.006   Prob(JB):                         0.00
# Kurtosis:                     124.400   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.7864168197354173, mean_val: 0.008074298409859659
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     13.46
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):           0.000248
# Time:                        23:36:56   Log-Likelihood:                -4236.0
# No. Observations:                2893   AIC:                             8476.
# Df Residuals:                    2891   BIC:                             8488.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                               0.0098      0.019      0.501      0.616      -0.028       0.048
# foreign_direct_investment_net_(bop_current_us$)    -0.0708      0.019     -3.669      0.000      -0.109      -0.033
# ==============================================================================
# Omnibus:                     4133.346   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           917538.438
# Skew:                           8.573   Prob(JB):                         0.00
# Kurtosis:                      88.544   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.8905928769554415, mean_val: -0.010185546909700836
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     2583.
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):               0.00
# Time:                        23:36:56   Log-Likelihood:                -3359.7
# No. Observations:                3212   AIC:                             6723.
# Df Residuals:                    3210   BIC:                             6736.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                      -0.0104      0.012     -0.855      0.392      -0.034       0.013
# foreign_direct_investment_net_inflows_(bop_current_us$)     0.6002      0.012     50.824      0.000       0.577       0.623
# ==============================================================================
# Omnibus:                     2879.545   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1064724.899
# Skew:                           3.382   Prob(JB):                         0.00
# Kurtosis:                      91.937   Cond. No.                         1.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test RMSE: 0.7610333534328274, mean_val: 0.009374785227213153
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     532.9
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):          1.08e-109
# Time:                        23:36:56   Log-Likelihood:                -4728.1
# No. Observations:                3423   AIC:                             9460.
# Df Residuals:                    3421   BIC:                             9473.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0063      0.016      0.381      0.703      -0.026       0.039
# forest_area_(sq._km)     0.3755      0.016     23.084      0.000       0.344       0.407
# ==============================================================================
# Omnibus:                     4849.251   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1335548.202
# Skew:                           8.351   Prob(JB):                         0.00
# Kurtosis:                      98.316   Cond. No.                         1.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 24
#      21 y_pred = lin_reg.predict(X_test)
#      23 # Calculate MSE using the testing set
# ---> 24 mse = ((y_test - y_pred) ** 2).mean()
#      26 print(f"Test RMSE: {math.sqrt(mse)}, mean_val: {y_pred.mean()}")
#      27 print(lin_reg.summary())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:7644, in DataFrame._arith_method(self, other, op)
#    7641 axis: Literal[1] = 1  # only relevant for Series other case
#    7642 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 7644 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7646 with np.errstate(all="ignore"):
#    7647     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:7926, in DataFrame._align_for_op(self, other, axis, flex, level)
#    7924 if not left._indexed_same(right):
#    7925     if flex:
# -> 7926         left, right = left.align(
#    7927             right, join="outer", level=level, copy=False
#    7928         )
#    7929     else:
#    7930         raise ValueError(
#    7931             "Can only compare identically-labeled (both index and columns) "
#    7932             "DataFrame objects"
#    7933         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:10078, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10076     axis = self._get_axis_number(axis)
#   10077 if isinstance(other, ABCDataFrame):
# > 10078     left, _right, join_index = self._align_frame(
#   10079         other,
#   10080         join=join,
#   10081         axis=axis,
#   10082         level=level,
#   10083         copy=copy,
#   10084         fill_value=fill_value,
#   10085         method=method,
#   10086         limit=limit,
#   10087         fill_axis=fill_axis,
#   10088     )
#   10090 elif isinstance(other, ABCSeries):
#   10091     left, _right, join_index = self._align_series(
#   10092         other,
#   10093         join=join,
#    (...)
#   10100         fill_axis=fill_axis,
#   10101     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:10153, in NDFrame._align_frame(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10144     join_index, ilidx, iridx = self.index.join(
#   10145         other.index, how=join, level=level, return_indexers=True
#   10146     )
#   10148 if (
#   10149     (axis is None or axis == 1)
#   10150     and not is_series
#   10151     and not self.columns.equals(other.columns)
#   10152 ):
# > 10153     join_columns, clidx, cridx = self.columns.join(
#   10154         other.columns, how=join, level=level, return_indexers=True
#   10155     )
#   10157 if is_series:
#   10158     reindexers = {0: [join_index, ilidx]}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:266, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     256 @functools.wraps(meth)
#     257 def join(
#     258     self,
#    (...)
#     264     sort: bool = False,
#     265 ):
# --> 266     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     267     if not return_indexers:
#     268         return join_index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:4660, in Index.join(self, other, how, level, return_indexers, sort)
#    4658     this = self.astype(dtype, copy=False)
#    4659     other = other.astype(dtype, copy=False)
# -> 4660     return this.join(other, how=how, return_indexers=True)
#    4662 _validate_join_method(how)
#    4664 if not self.is_unique and not other.is_unique:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:266, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     256 @functools.wraps(meth)
#     257 def join(
#     258     self,
#    (...)
#     264     sort: bool = False,
#     265 ):
# --> 266     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     267     if not return_indexers:
#     268         return join_index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:4672, in Index.join(self, other, how, level, return_indexers, sort)
#    4667 if self.is_monotonic_increasing and other.is_monotonic_increasing:
#    4668     if not isinstance(self.dtype, IntervalDtype):
#    4669         # otherwise we will fall through to _join_via_get_indexer
#    4670         # GH#39133
#    4671         # go through object dtype for ea till engine is supported properly
# -> 4672         return self._join_monotonic(other, how=how)
#    4673 else:
#    4674     return self._join_non_unique(other, how=how)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:5019, in Index._join_monotonic(self, other, how)
#    5017     join_array, lidx, ridx = self._inner_indexer(other)
#    5018 elif how == "outer":
# -> 5019     join_array, lidx, ridx = self._outer_indexer(other)
#    5021 assert lidx is not None
#    5022 assert ridx is not None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:420, in Index._outer_indexer(self, other)
#     418 sv = cast(np.ndarray, sv)
#     419 ov = cast(np.ndarray, ov)
# --> 420 joined_ndarray, lidx, ridx = libjoin.outer_join_indexer(sv, ov)
#     421 joined = self._from_join_target(joined_ndarray)
#     422 return joined, lidx, ridx
#
# File join.pyx:580, in pandas._libs.join.outer_join_indexer()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
y_pred
# Out:
#              0         1
# 2271 -0.180519 -0.180519
# 3142  0.065255  0.065255
# 2032 -0.096325 -0.096325
# 3897 -0.220019 -0.220019
# 918  -0.210878 -0.210878
# ...        ...       ...
# 3942 -0.206310 -0.206310
# 2021 -0.162338 -0.162338
# 3960 -0.190530 -0.190530
# 2485 -0.212890 -0.212890
# 156   0.180272  0.180272
#
# [871 rows x 2 columns]

# %%
good_features
# Out:
# ['external_debt_stocks_total_(dod_current_us$)',
#  'foreign_direct_investment_net_inflows_(bop_current_us$)',
#  'forest_area_(sq._km)']

# %%
df_v2 = df_restructured[['foreign_direct_investment_net_inflows_(bop_current_us$)',
 'external_debt_stocks_total_(dod_current_us$)',
 'forest_area_(sq._km)',
 'net_migration',
 'population_total',
 'surface_area_(sq._km)',
 'gdp_(current_us$)']].dropna()
    
scaled_array = scaler.fit_transform(df_v2)
df_v2 = pd.DataFrame(scaled_array, columns=df_v2.columns)

X = df_v2.drop(columns = 'gdp_(current_us$)')
y = df_v2['gdp_(current_us$)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 1234)

X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

lin_reg = sm.OLS(y_train, X_train).fit()

# Predict on the testing set
y_pred = lin_reg.predict(X_test)

# Calculate MSE using the testing set
mse = ((y_test - y_pred) ** 2).mean()

print(f"Test RMSE: {math.sqrt(mse)}, mean_val: {y_pred.mean()}")
print(lin_reg.summary())
# Out:
# Test RMSE: 0.25677338386118415, mean_val: 0.021450563379305697
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      gdp_(current_us$)   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     4481.
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):               0.00
# Time:                        23:35:21   Log-Likelihood:                -228.18
# No. Observations:                1938   AIC:                             470.4
# Df Residuals:                    1931   BIC:                             509.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# const                                                       0.0023      0.006      0.365      0.715      -0.010       0.014
# foreign_direct_investment_net_inflows_(bop_current_us$)     0.4800      0.015     31.895      0.000       0.450       0.509
# external_debt_stocks_total_(dod_current_us$)                0.5500      0.014     40.382      0.000       0.523       0.577
# forest_area_(sq._km)                                       -0.1794      0.020     -9.117      0.000      -0.218      -0.141
# net_migration                                               0.0139      0.006      2.166      0.030       0.001       0.026
# population_total                                            0.0730      0.011      6.814      0.000       0.052       0.094
# surface_area_(sq._km)                                       0.0550      0.022      2.520      0.012       0.012       0.098
# ==============================================================================
# Omnibus:                     1745.800   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           546130.931
# Skew:                           3.400   Prob(JB):                         0.00
# Kurtosis:                      84.957   Cond. No.                         8.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
